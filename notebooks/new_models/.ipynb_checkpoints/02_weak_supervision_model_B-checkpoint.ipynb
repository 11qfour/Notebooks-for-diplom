# %%
import pandas as pd
import numpy as np
import torch
import joblib
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from sklearn.metrics import classification_report, f1_score
# Out:
# W0504 07:18:28.960000 25376 Lib\site-packages\torch\distributed\elastic\multiprocessing\redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.

# %%
DATA_PATH = "../data/processed/"
#энкодер от модели А
label2id = joblib.load("../../label_encoder_model_a.joblib")
id2label = {i: label for label, i in label2id.items()}

train_df = pd.read_csv(DATA_PATH + "weak_train_45k.csv")
test_df = pd.read_csv(DATA_PATH + "gold_test_holdout.csv")

# %%
#мап меток в ID
train_df['label'] = train_df['label'].map(label2id)
test_df['label'] = test_df['label'].map(label2id)
#подготовка датасета
MODEL_NAME = "cointegrated/rubert-tiny"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

def tokenize_func(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=128)

train_ds = Dataset.from_pandas(train_df)
test_ds = Dataset.from_pandas(test_df)

train_ds = train_ds.map(tokenize_func, batched=True)
test_ds = test_ds.map(tokenize_func, batched=True)
# Out:
# ...
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
training_args = TrainingArguments(
    output_dir="./saved_model_B_weak",
    num_train_epochs=3,
    per_device_train_batch_size=32,
    learning_rate=5e-5,
    weight_decay=0.01,
    logging_steps=100,
    save_strategy="no",
    report_to="none"
)

def model_init():
    return AutoModelForSequenceClassification.from_pretrained(
        MODEL_NAME, num_labels=len(label2id), id2label=id2label, label2id=label2id
    )

trainer = Trainer(
    model_init=model_init,
    args=training_args,
    train_dataset=train_ds
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def model_init():
    return AutoModelForSequenceClassification.from_pretrained(
        MODEL_NAME, num_labels=len(label2id), id2label=id2label, label2id=label2id
    )

trainer = Trainer(
    model_init=model_init,
    args=training_args,
    train_dataset=train_ds
)

print("Запуск обучения Модели Б на 45 500 строках...")
trainer.train()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Запуск обучения Модели Б на 45 500 строках...
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# D:\projects\context\contextual_search\venv\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
# ...

# %%
trainer.save_model("./saved_model_B_epoch_1")

# 2. Делаем предсказание на тесте
print("🔍 Тестируем модель Б после 1-й эпохи...")
preds = trainer.predict(test_ds)
y_pred = np.argmax(preds.predictions, axis=-1)
y_true = test_df['label'].values # убедись, что колонка называется 'label' или как ты её назвал

# 3. Выводим отчет
print("\n📊 ОТЧЕТ МОДЕЛИ Б (Weak Supervision):")
print(classification_report(y_true, y_pred, target_names=list(label2id.keys())))
# Out:
# 🔍 Тестируем модель Б после 1-й эпохи...
# D:\projects\context\contextual_search\venv\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 📊 ОТЧЕТ МОДЕЛИ Б (Weak Supervision):
#                                        precision    recall  f1-score   support
#
#                APP_API_AUTH_500_ERROR       0.00      0.00      0.00         6
#          APP_CARD_AUTH_BUSINESS_ERROR       0.00      0.00      0.00         4
# APP_FINBANK_FUNCTIONAL_UNAVAILABILITY       0.00      0.00      0.00         1
#              APP_INTERNAL_ERROR_CODES       0.00      0.00      0.00         2
#                               APP_ZOD       0.00      0.00      0.00         1
#                                 EMAIL       0.00      0.00      0.00         1
#              INFRA_CONNECTION_REFUSED       0.00      0.00      0.00         1
# ...

# %%
print(train_df['label'].value_counts())
# Out:
# label
# 27    44294
# Name: count, dtype: int64
